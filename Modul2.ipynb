# %% [markdown]
# # Data Analysis With Python ☝️🤗

# %% [markdown]
# ## ✨  Introduction
# **What is Data and Information?**

# %% [markdown]
# ## ✨  Flow of a data analysis process

# %% [markdown]
# 1. Questions
# is defining data analysis questions, the concept of 4W (What, Why, When, Where) is often used.
# 2. Data Wrangling
# In this stage, you will perform data gathering and data cleaning processes.
# 3. Exploratory Data Analysis (EDA)
# Explore the cleaned data to obtain insights and answer analysis questions.
# 4. Data Visualization
# EDA needs to be visualized, paying attention to the appropriate techniques and types of data visualization to communicate insights.
# 5. Draw Conclusion & Communicate
# At the end of the data analysis project, we need to draw conclusions from the analysis results. The conclusions made should answer all the questions and objectives defined at the beginning.

# %% [markdown]
# ## ✨ Data Type

# %% [markdown]
# 1. Data kuantitatif : Data that is represented in numerical scale and can undergo mathematical operations.
#
#     a. Continuous data : numerical values such as decimals, integers, etc
#
#       - Example : Age, body height, body weight
#
#     b. Discrete data :Can only be represented in integers and cannot be divided into smaller units
#
#       - Example : The number of cats, sales
#
# 2. Categorical
#
#     a. Ordinal data : Categorical data sorted based on rating
#
#       - Example : Rating,  customer categories based on income
#
#     b. Nominal data : A type of categorical data that does not have order or ranking.
#
#       - Example : Gender, fur color of cats

# %% [markdown]
# ## ✨ Basic Descriptive Statistic

# %% [markdown]
# By definition, statistik merupakan ilmu yang menerapkan berbagai metode saintifik dalam proses pengumpulan, analisis, interpretasi, serta penyajian data.
#
# digunakan untuk mendeskripsikan sebuah data yang dikenal sebagai descriptive statistics. Beberapa konsep tersebut bisa Anda lihat di bawah ini.
#
# - Measuring central tendency untuk mengidentifikasi nilai khas atau sentral dalam sebuah data.
# - Measuring dispersion untuk menilai variabilitas atau sebaran nilai dalam sebuah data.
# - Measuring asymmetric untuk menilai ketidaksimetrisan dalam sebuah distribusi data.
# - Data relationship untuk mengidentifikasi hubungan dua atau lebih feature/column/variable dalam sebuah data.

# %% [markdown]
# ### 🐳 Measuring central tendency
# The typical or central value is represented using three statistical parameters: mean, median, and mode.

# %% [markdown]
# #### ✨ Mean (average)
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

gudetamas = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
gudetamas.mean()
# Out:
# 1.7

# %% [markdown]
# #### ✨ Median (Middle Value Of The Sorted Data )
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

gudetamas = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
np.median(gudetamas)
# Out:
# 2.0

# %% [markdown]
# #### ✨ Mode (Value that appears most frequently )
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from scipy import stats

gudetamas = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
mode_gudetamas = stats.mode(gudetamas)[0]

print(mode_gudetamas)
# Out:
# 2

# %% [markdown]
# ### 🐳 Measuring Dispersion
# To describe measuring dispersion, we can use four parameters, namely range, interquartile range, variance, and standard deviation.

# %% [markdown]
# #### ✨ Range (The difference between the maximum and minimum values)
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

gudetamas = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
range = gudetamas.max() - gudetamas.min()
print(range)
# Out:
# 3

# %% [markdown]
# #### ✨ Interquartile Range (A statistical parameter that describes the difference between the third quartile (Q3) and the first quartile (Q1))
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

gudetamas = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
iqr = np.percentile(gudetamas, 75) - np.percentile(gudetamas, 25)
print(iqr)
# Out:
# 1.0

# %% [markdown]
# #### ✨ Variance (The magnitude of deviation of a data point from its mean value.)
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd

gudetamas = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
gudetamas_series = pd.Series(gudetamas)
gudetamas_series.var()
# Out:
# 0.9000000000000001

# %% [markdown]
# #### ✨ Standard Deviation (The square root of the variance.)
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd

gudetamas = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
gudetamas_series = pd.Series(gudetamas)
gudetamas_series.std()
# Out:
# 0.9486832980505139

# %%
#### ✨ Standard Deviation (The square root of the variance.)

# %% [markdown]
# ### 🐳 Measuring Asymmetric
# Used to identify asymmetry in a distribution of numerical data.

# %% [markdown]
# #### ✨ Distribusi Data (To indicate the frequency of a value appearing in a dataset.)
#
#
# - Symmetric distribution (normal distribution atau bell curve distribution)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Right-skewed distribution (Most of the population data is concentrated on the left side.)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Left-skewed distribution (Most of the population data is concentrated on the right side)
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

gudetamas = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
plt.hist(gudetamas, bins=4)
plt.show()

# %% [markdown]
# #### ✨ Skewness
#
# - Positive skewness indicates that the data has a distribution that tends to be right-skewed.
# - Zero skewness indicates that the data has a perfectly symmetric distribution.
# - Negative skewness indicates that the data has a distribution that tends to be left-skewed.

# %%
import numpy as np
import pandas as pd

gudetamas = np.array([3, 2, 1, 1, 2, 3, 2, 1, 0, 2])
gudetamas_series = pd.Series(gudetamas)
gudetamas_series.skew()
# Out:
# -0.2342427896421018

# %% [markdown]
# The value indicates that our data tends to have a left-skewed distribution.

# %% [markdown]
# ### 🐳 Data Relationship (Identifying relationships between numeric features in a dataset)

# %% [markdown]
# - Correlation
#
# A negative value represents inverse correlation (negative correlation), while a positive value represents direct correlation (positive correlation). If the correlation between two features is zero, they are considered to have no correlation (no correlation).
#
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

camin_kcv = {
    'name': ['Anne', 'Anna', 'Anny', 'Annu', 'Anno'],
    'age': [19, 18, 18, 20, 17],
    'leadership_skill_score': [85, 70, 75, 90, 90],
    'hard_skill_score': [80, 90, 80, 75, 70]
}

df = pd.DataFrame(camin_kcv)

df.corr(numeric_only=True)
# Out:
#                              age  leadership_skill_score  hard_skill_score
# age                     1.000000                0.265543          0.059131
# leadership_skill_score  0.265543                1.000000         -0.890724
# hard_skill_score        0.059131               -0.890724          1.000000

# %% [markdown]
# - Covariance
#
# a. Positive covariance represents two features that are positively correlated or in agreement.
#
# b. Negative covariance represents two features that are negatively correlated or opposed.
#
# c. Zero covariance indicates two features that are not correlated with each other.

# %%
import pandas as pd

camin_kcv = {
    'name': ['Anne', 'Anna', 'Anny', 'Annu', 'Anno'],
    'age': [19, 18, 18, 20, 17],
    'leadership_skill_score': [85, 70, 75, 90, 90],
    'hard_skill_score': [80, 90, 80, 75, 70]
}

df = pd.DataFrame(camin_kcv)

df.cov(numeric_only=True)
# Out:
#                          age  leadership_skill_score  hard_skill_score
# age                     1.30                    2.75               0.5
# leadership_skill_score  2.75                   82.50             -60.0
# hard_skill_score        0.50                  -60.00              55.0

# %% [markdown]
# ## ✨ Data Wrangling

# %% [markdown]
# a. Gathering data :  collect all the data needed to address all the questions or problems
#
# b. Assessing data : this process aims to identify various issues within the data, such as missing values, non-standard values, etc.
#
# c. Cleaning Data

# %% [markdown]
# ### a. Gathering Data

# %% [markdown]
# #### 🌸Source Data

# %% [markdown]
# - Kaggle
# ![image.png](data:image/png;base64,...)
#
# - UCI Machine Learning Repository
#
# ![image.png](data:image/png;base64,...)
#
# - Google Dataset Search
# - Satu Data Indonesia
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### 🌸Read data using Pandas

# %%
import pandas as pd

df_csv = pd.read_csv("data.csv", delimiter=",")
df_excel = pd.read_excel("data.xlsx", sheet_name="Sheet1")
df_json = pd.read_json("data.json")

url = "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list"
df_html = pd.read_html(url)[0]
df_xml = pd.read_xml("https://www.w3schools.com/xml/books.xml")

# %% [markdown]
# - access from SQL database

# %%
import pandas as pd
import sqlalchemy as sqla

db_sql = sqla.create_engine("sqlite:///mydata.sqlite")

pd.read_sql_table("table_name", db_sql)
pd.read_sql_query("SELECT * FROM table_name", db_sql)
pd.read_sql("SELECT * FROM table_name", db_sql)

# %% [markdown]
# #### 🌸 combine multiple data into one DataFrame

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Based on the way they are merged, the merge or join process can be divided into four types as follows.
# - Inner Join :  takes matching values from both tables
# - Left Join : take all values from the left table along with matching values from the right table
# - Right Join : take all values from the right table along with matching values from the left table
# - Outer join : take all values from both tables.

# %%
import pandas as pd

product_df = pd.read_csv("product.csv")
orders_df = pd.read_csv("orders.csv")

new_order_df = pd.merge(
    left=product_df,
    right=orders_df,
    how="inner",
    left_on="product_id",
    right_on="product_id"
)

# %% [markdown]
# ### b. Assessing Data

# %% [markdown]
# #### 🍀Common Problems Encountered in Data
#
# The collected data must be examined first before entering the analysis stage.

# %% [markdown]
# - Missing Values:
# This problem arises due to the absence of values in a dataset and is usually represented as NaN (Not a Number) values in the pandas library. This typically occurs due to human error, privacy concerns, merging/joining processes, etc.

# %%
import pandas as pd

prduct_df = pd.read_csv("product.csv")
product_df.isnull().sum()
#product_df.isna().sum()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Invalid Value : This problem arises when there are values that are illogical, do not comply with specifications, or the background knowledge of the data.

# %% [markdown]
# - Duplicate Data: Duplicate data is another common problem encountered in industries. It occurs when an observation (all values in a single row) has exactly the same values in each column.

# %%
import pandas as pd
url = "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list"
df = pd.read_html(url)[0]
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - Inaccurate Values: Inaccurate values occur when the values in a dataset do not match the observation results.
#
# - Inconsistent Values: Inconsistent values are values in data that are inconsistent in terms of units or assessment criteria.
#
# - Outliers:Outliers, also known as anomalies, are data points that are significantly different from other data points in a dataset. These significantly different values will affect several statistical parameters used to analyze data, such as mean and standard deviation.
#
# There are several methods that can be used to identify outliers in a dataset. The most commonly used method is the IQR (Interquartile Range) method. IQR identifies outliers by creating cut-off values as a factor (usually we use a value from 1.5 to 3) of the IQR value. These cut-off values are then used to calculate boundary values. The values are divided into two: minimum and maximum thresholds. All data points smaller than the minimum threshold or larger than the maximum threshold are considered outliers.

# %%
import numpy as np
import seaborn as sns

data = [6, 2, 3, 4, 5, 1, 50]
sort_data = np.sort(data)
sort_data

# Percentile : The value that divides the data into one hundred equal parts.
Q1 = np.percentile(data, 25, interpolation = 'midpoint')
Q2 = np.percentile(data, 50, interpolation = 'midpoint')
Q3 = np.percentile(data, 75, interpolation = 'midpoint')

print('Q1 25 percentile of the given data is, ', Q1)
print('Q1 50 percentile of the given data is, ', Q2)
print('Q1 75 percentile of the given data is, ', Q3)

IQR = Q3 - Q1
print('Interquartile range is', IQR)
# Out:
# Q1 25 percentile of the given data is,  2.5
# Q1 50 percentile of the given data is,  4.0
# Q1 75 percentile of the given data is,  5.5
# Interquartile range is 3.0

# %%
# Find the lower and upper limits as Q1 – 1.5 IQR and Q3 + 1.5 IQR, respectively.
low_lim = Q1 - 1.5 * IQR
up_lim = Q3 + 1.5 * IQR
print('low_limit is', low_lim)
print('up_limit is', up_lim)
# Out:
# low_limit is -2.0
# up_limit is 10.0

# %%
# Data points greater than the upper limit or less than the lower limit are outliers
outlier =[]
for x in data:
    if ((x> up_lim) or (x<low_lim)):
         outlier.append(x)
print(' outlier in the dataset is', outlier)
# Out:
#  outlier in the dataset is [50]

# %%
# Plot the box plot to highlight outliers.
sns.boxplot(data)
# Out:
# <Axes: >

# %%
# Calculate IQR
from scipy import stats
IQR = stats.iqr(data, interpolation = 'midpoint')
IQR
# Out:
# 3.0

# %% [markdown]
# ### c. Cleaning Data

# %% [markdown]
# #### 🍀 Techniques for Handling Missing Values
# a. Dropping : Remove entire rows or columns that contain missing values

# %%
import pandas as pd

products_df = pd.read_csv("product.csv")
products_df.dropna(axis=0, inplace=True)

# %% [markdown]
# b. Imputation : Filling missing values with certain values
#
# For continuous data, we can use the mean, median, or mode as replacements for missing values. If working with categorical data, we can fill missing values with the most frequently occurring category.

# %%
import pandas as pd

data = pd.read_csv('employee_data.csv')
data.age.fillna(value=data.age.mean(), inplace=True)

# %% [markdown]
# c. Interpolation
# Interpolation is a numerical approach used to calculate new data points based on the existing data range.  This calculation uses a linear or polynomial equation. This calculation makes this method very suitable for handling missing values in time series data.

# %%
import pandas as pd

data = pd.read_csv('bbca_index.csv')
data.close_price.interpolate(method='linear', limit_direction='forward', inplace=True)

# %% [markdown]
# #### 🍀 Techniques for Handling Outliers

# %% [markdown]
# a. Dropping : The first method, which is the easiest, is to drop or remove all rows containing outliers.

# %%
import pandas as pd

df = pd.read_csv("data.csv")

Q1 = df['TotalCharges'].quantile(0.25)
Q3 = df['TotalCharges'].quantile(0.75)
IQR = Q3 - Q1

maximum = Q3 + (1.5*IQR)
minimum = Q1 - (1.5*IQR)

condition_lower_than = df['TotalCharges'] < minimum
condition_more_than = df['TotalCharges'] > maximum

df.drop(df[condition_lower_than].index, inplace=True)
df.drop(df[condition_more_than].index, inplace=True)

# %% [markdown]
# b. Imputation : The concept is similar to the previous method, which is replacing outliers with certain values. The values we can use are the mean, median, mode, or boundary values.

# %%
import pandas as pd
df = pd.read_csv("data.csv")

Q1 = df['TotalCharges'].quantile(0.25)
Q3 = df['TotalCharges'].quantile(0.75)
IQR = Q3 - Q1

maximum = Q3 + (1.5*IQR)
minimum = Q1 - (1.5*IQR)

condition_lower_than = df['TotalCharges'] < minimum
condition_more_than = df['TotalCharges'] > maximum

df.mask(cond=condition_more_than, maximum, axis=1, inplace=True)
df.mask(cond=condition_lower_than, minimum, axis=1, inplace=True)

# %% [markdown]
# c. Handling Duplicate Data : When encountering duplicate data, we need to remove or delete those duplicates. If the number of duplicates and the size of the data are small, we might be able to delete them manually.

# %%
import pandas as pd

df = pd.read_csv("data.csv")
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## ✨ Exploratory Data Analysis

# %% [markdown]
# EDA (Exploratory Data Analysis) is a stage of exploring cleaned data to gain insights and answer analysis questions.

# %% [markdown]
# ### 🌸Statistic Parameter

# %% [markdown]
# - describe() :
# This method allows us to view summary statistics (mean, median, etc.) of numeric columns in a DataFrame.

# %%
import pandas as pd

city_names = ['Jakarta', 'Bandung', 'Makassar', 'Surabaya', 'Medan', 'Yogyakarta', 'Malang']
population = [498044, 964254, 491918, 8398748, 653115, 883305, 744955]
num_airports = [2, 2, 8, 3, 1, 3, 2]

df = pd.DataFrame({
  'City Name': city_names,
  'Population': population,
  'Airports': num_airports,
})

df.describe(include="all")
# Out:
#        City Name    Population  Airports
# count          7  7.000000e+00  7.000000
# unique         7           NaN       NaN
# top      Jakarta           NaN       NaN
# freq           1           NaN       NaN
# mean         NaN  1.804906e+06  3.000000
# std          NaN  2.913095e+06  2.309401
# min          NaN  4.919180e+05  1.000000
# 25%          NaN  5.755795e+05  2.000000
# 50%          NaN  7.449550e+05  2.000000
# 75%          NaN  9.237795e+05  3.000000
# max          NaN  8.398748e+06  8.000000

# %% [markdown]
# - hist() : Make histogram plot from numerical column in a Datatframe

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Population'}>,
#         <Axes: title={'center': 'Airports'}>]], dtype=object)

# %% [markdown]
# - corr() or cov() : To check the correlation between numeric data in a DataFrame.

# %%
df.corr()
# Out:
# <ipython-input-24-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#             Population  Airports
# Population    1.000000 -0.026109
# Airports     -0.026109  1.000000

# %% [markdown]
# ### 🌸Grouping Data

# %% [markdown]
# We can use the concept of a pivot table to calculate statistical parameters for specific groups of data
#
# 🔑Key: a column containing categorical data used to group the data.
#
# 🍀Value: a column containing quantitative data whose statistical parameters will be calculated.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Groupby()

# %%
import pandas as pd

body_measurement_df = pd.DataFrame.from_records((
  (2, 83.82, 8.4),
  (4, 99.31, 16.97),
  (3, 96.52, 14.41),
  (6, 114.3, 20.14),
  (4, 101.6, 16.91),
  (2, 86.36, 12.64),
  (3, 92.71, 14.23),
  (2, 85.09, 11.11),
  (2, 85.85, 14.18),
  (5, 106.68, 20.01),
  (4, 99.06, 13.17),
  (5, 109.22, 15.36),
  (4, 100.84, 14.78),
  (6, 115.06, 20.06),
  (2, 84.07, 10.02),
  (7, 121.67, 28.4),
  (3, 94.49, 14.05),
  (6, 116.59, 17.55),
  (7, 121.92, 22.96),
), columns=("age", "height_cm", "weight_kg"))

body_measurement_df.groupby(by="age").mean()
# Out:
#       height_cm  weight_kg
# age
# 2     85.038000    11.2700
# 3     94.573333    14.2300
# 4    100.202500    15.4575
# 5    107.950000    17.6850
# 6    115.316667    19.2500
# 7    121.795000    25.6800

# %%
# More than one parameter
body_measurement_df.groupby(by='age').agg({
    'height_cm': 'mean',
    'weight_kg': ['mean','max', 'min'],
})
# Out:
#       height_cm weight_kg
#            mean      mean    max    min
# age
# 2     85.038000   11.2700  14.18   8.40
# 3     94.573333   14.2300  14.41  14.05
# 4    100.202500   15.4575  16.97  13.17
# 5    107.950000   17.6850  20.01  15.36
# 6    115.316667   19.2500  20.14  17.55
# 7    121.795000   25.6800  28.40  22.96

# %% [markdown]
# ## ✨ Data Visualiation

# %% [markdown]
# ### 🍀Principles of Design in Data Visualization

# %% [markdown]
# - Position: This element helps us represent data points using specific axes (such as the X, Y, and Z axes) as references.
#
# - Size: Size (length or width) is a visual element commonly used to differentiate and compare values of specific categories or data points.
#
# - Shape: Shape is one visual element that can be used to differentiate specific categories or data points.
#
# - Color: Besides shape, color is another visual element that can be used to differentiate specific categories or data points. When using color, we must remember that not everyone can perceive colors well.
#
# - Texture: Adding specific textures or patterns can be another alternative to differentiate specific categories or data points.
#
# - Angle: In some visualization options, angles are used as visual elements to represent the values of data.

# %% [markdown]
# ### 🍀 Univariate Visualization

# %% [markdown]
# - Univariate visualization is a form of data visualization that represents information contained within a single variable.

# %% [markdown]
# Bar Chart
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Pie Chart
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Histogram
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Box Plot
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🍀Bivariate dan Multivariate Visualization

# %% [markdown]
# Bivariate visualization is a form of data visualization used to present information from two variables in a dataset.

# %% [markdown]
# Scatter Plot
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Line Chart
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ✨ Implemetation

# %% [markdown]
# Dataset : https://www.kaggle.com/competitions/titanic/data

# %% [markdown]
# ### ❔ Menentukan Pertanyaan Bisnis

# %% [markdown]
# 1. Survival patterns based on passenger gender
# 2. Relationship between ticket class and passenger survival rate
# 3. Influence of the number of siblings/spouses and parents/children on passenger survival rate
# 4. Distribution of embarkation locations for survived vs. not survived passengers
# 5. Distribution of passenger age for survived vs. not survived passengers
# 6. Correlation between presence of cabin information in the "Cabin" column and survival rate

# %% [markdown]
# ### 📚 Import Library/Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
# %matplotlib inline
import seaborn as sns
sns.set() # setting seaborn default for plots

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### ☘️ Data Wrangling

# %% [markdown]
# #### Gathering Data

# %%
dft = pd.read_csv("/content/drive/MyDrive/KCV 2023/OPREC 2024/Dataset/titanic/train.csv")
dft.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# #### Assessing Data

# %%
# Check the data types
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Check statistic parameters
dft.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# In the training set:
#
# 38.3% people survived
# More number of people were actually in 3rd class
# 50% of passengers were in between the age of 20 to 38

# %%
# Missing Values
dft.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Duplicated
dft.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Data Dictionary
# - Survived: 0 = No, 1 = Yes
# - pclass: Ticket class 1 = 1st, 2 = 2nd, 3 = 3rd
# - sibsp: # of siblings / spouses aboard the Titanic
# - parch: # of parents / children aboard the Titanic
# - ticket: Ticket number
# - cabin: Cabin number
# - embarked: Port of Embarkation C = Cherbourg, Q = Queenstown, S = Southampton
#
# Problems:
# 1. There are 177 missing values in the age column.
# 2. There are 687 missing values in the cabin
#  column.
# 3. There are 2 missing values in the embarked column.

# %% [markdown]
# ##### Age

# %%
sns.distplot(dft['Age'])
# Out:
# <ipython-input-50-80086291e797>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dft['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(dft['Age'])
# Out:
# <Axes: ylabel='Age'>

# %% [markdown]
# ##### Fare

# %%
sns.distplot(dft['Fare'])
# Out:
# <ipython-input-52-af9d797f04ae>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dft['Fare'])
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
sns.boxplot(dft['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %% [markdown]
# Highly skewed data, a lot of people had cheaper tickets
#
# Outliers are there in the data

# %% [markdown]
# #### 🧹 Cleaning Data

# %%
#Dropping the PassengerId and Ticket column as it won't be used in the future.
dft.drop(["PassengerId",'Ticket'],axis = 1,inplace = True)
dft
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Cabin Embarked
# ...

# %%
dft['Age'].fillna(dft['Age'].median(), inplace=True)

dft.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ### 📊 EDA and Visualiation

# %%
def bar_chart(feature):
    survived = dft[dft['Survived']==1][feature].value_counts()
    dead = dft[dft['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

bar_chart('Sex')
print("Survived :\n",dft[dft['Survived']==1]['Sex'].value_counts())
print("Dead:\n",dft[dft['Survived']==0]['Sex'].value_counts())
# Out:
# Survived :
#  female    233
# male      109
# Name: Sex, dtype: int64
# Dead:
#  male      468
# female     81
# Name: Sex, dtype: int64

# %% [markdown]
# The Chart confirms Women more likely survivied than Men.

# %%
bar_chart('Pclass')
print("Survived :\n",dft[dft['Survived']==1]['Pclass'].value_counts())
print("Dead:\n",dft[dft['Survived']==0]['Pclass'].value_counts())
# Out:
# Survived :
#  1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64
# Dead:
#  3    372
# 2     97
# 1     80
# Name: Pclass, dtype: int64

# %% [markdown]
# The Chart confirms 1st class more likely survivied than other classes.
#
# The Chart confirms 3rd class more likely dead than other classes

# %%
bar_chart('SibSp')
print("Survived :\n",dft[dft['Survived']==1]['SibSp'].value_counts())
print("Dead:\n",dft[dft['Survived']==0]['SibSp'].value_counts())
# Out:
# Survived :
#  0    210
# 1    112
# 2     13
# 3      4
# 4      3
# Name: SibSp, dtype: int64
# Dead:
#  0    398
# 1     97
# 4     15
# 2     15
# 3     12
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %% [markdown]
# The Chart confirms a person aboarded with more than 2 siblings or spouse more likely survived.
#
# The Chart confirms a person aboarded without siblings or spouse more likely dead

# %%
bar_chart('Parch')
print("Survived :\n",dft[dft['Survived']==1]['Parch'].value_counts())
print("Dead:\n",dft[dft['Survived']==0]['Parch'].value_counts())
# Out:
# Survived :
#  0    233
# 1     65
# 2     40
# 3      3
# 5      1
# Name: Parch, dtype: int64
# Dead:
#  0    445
# 1     53
# 2     40
# 5      4
# 4      4
# 3      2
# 6      1
# Name: Parch, dtype: int64

# %% [markdown]
# The Chart confirms a person aboarded with more than 2 parents or children more likely survived.
# The Chart confirms a person aboarded alone more likely dead

# %%
bar_chart('Embarked')
print("Survived :\n",dft[dft['Survived']==1]['Embarked'].value_counts())
print("Dead:\n",dft[dft['Survived']==0]['Embarked'].value_counts())
# Out:
# Survived :
#  S    217
# C     93
# Q     30
# Name: Embarked, dtype: int64
# Dead:
#  S    427
# C     75
# Q     47
# Name: Embarked, dtype: int64

# %% [markdown]
# The Chart confirms a person aboarded from C slightly more likely survived.
#
# The Chart confirms a person aboarded from Q more likely dead.
#
# The Chart confirms a person aboarded from S more likely dead.

# %%
survived_fare = dft[dft['Survived'] == 1]['Fare']
not_survived_fare = dft[dft['Survived'] == 0]['Fare']
print("\nSurvived Passenger Fare Distribution:\n", survived_fare.describe())
print("\nNot Survived Passenger Fare Distribution:\n", not_survived_fare.describe())
# Out:
# Survived Passenger Fare Distribution:
#  count    342.000000
# mean      48.395408
# std       66.596998
# min        0.000000
# 25%       12.475000
# 50%       26.000000
# 75%       57.000000
# max      512.329200
# Name: Fare, dtype: float64
#
# Not Survived Passenger Fare Distribution:
#  count    549.000000
# mean      22.117887
# std       31.388207
# min        0.000000
# 25%        7.854200
# 50%       10.500000
# 75%       26.000000
# max      263.000000
# Name: Fare, dtype: float64

# %%
# Plotting the distribution of age for survived passengers
plt.figure(figsize=(10, 6))
plt.hist(survived_age.dropna(), bins=20, color='green', alpha=0.7, label='Survived')
plt.axvline(survived_age.mean(), color='green', linestyle='dashed', linewidth=1.5, label='Mean Age (Survived)')
plt.title('Distribution of Age for Survived Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# Plotting the distribution of age for not survived passengers
plt.figure(figsize=(10, 6))
plt.hist(not_survived_age.dropna(), bins=20, color='red', alpha=0.7, label='Not Survived')
plt.axvline(not_survived_age.mean(), color='red', linestyle='dashed', linewidth=1.5, label='Mean Age (Not Survived)')
plt.title('Distribution of Age for Not Survived Passengers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.grid(True)
plt.show()

# %%
cabin_survival_corr = dft['Cabin'].notnull().corr(dft['Survived'])
print("\nCorrelation between Cabin Presence and Survival:", cabin_survival_corr)
# Out:
# Correlation between Cabin Presence and Survival: 0.3169115231122962
